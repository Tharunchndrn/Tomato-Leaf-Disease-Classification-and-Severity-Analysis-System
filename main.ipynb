# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from datasets import load_dataset

dataset = load_dataset("mohanty/plant_village", streaming=True)

# Access one sample
sample = next(iter(dataset("raw/color/Raspberry___healthy/a37f34f7-022d-461a-8a3d-95f5cd774e35___Mary_HL 9155.JPG")))
print(sample)
# Out:
# Using the latest cached version of the dataset since mohanty/plant_village couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Taruni\.cache\huggingface\datasets\mohanty___plant_village\default\0.0.0\9e97599868962bd0079b8db4b7f1efa9185fa1e7 (last modified on Thu Apr 16 20:30:30 2026).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 dataset = load_dataset("mohanty/plant_village", streaming=True)
#       4
#       5 # Access one sample
# ----> 6 sample = next(iter(dataset("raw/color/Raspberry___healthy/a37f34f7-022d-461a-8a3d-95f5cd774e35___Mary_HL 9155.JPG")))
#       7 print(sample)
#
# TypeError: 'IterableDatasetDict' object is not callable
